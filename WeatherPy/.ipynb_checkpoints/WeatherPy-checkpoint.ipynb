# %% [markdown]
# # WeatherPy
# ----
#
# #### Maverick Sanchez

# %%
# %matplotlib inline

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import sys
from scipy.stats import linregress

#Import pprint
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
total_cities = len(cities)
total_cities
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
# cities

# %%
# Build query URL and request your results in Celsius
weather_url = "http://api.openweathermap.org/data/2.5/weather?"

# Get weather data
cities_weather = []
counter = 1

for city in cities:
    
    query_url = weather_url + 'appid=' + weather_api_key + '&units=imperial&q=' + city
    response = requests.get(query_url).json()
    
    try:
        print(f"Processing Record {counter}. Fetched {response['name']}.")
        cities_weather.append(response)
        counter = counter + 1
    except:
        print(f"{city} not found. Skipping.....")
# Out:
# Processing Record 0. Fetched Batticaloa.
# Processing Record 1. Fetched Atuona.
# Processing Record 2. Fetched Avarua.
# Processing Record 3. Fetched Mawlaik.
# Processing Record 4. Fetched Rikitea.
# Processing Record 5. Fetched Ponnani.
# Processing Record 6. Fetched Boa Vista.
# Processing Record 7. Fetched Rawalpindi.
# Processing Record 8. Fetched Olinda.
# Processing Record 9. Fetched Bredasdorp.
# Processing Record 10. Fetched Banda Aceh.
# Processing Record 11. Fetched Longyearbyen.
# Processing Record 12. Fetched Natchez.
# Processing Record 13. Fetched Karpathos.
# Processing Record 14. Fetched Bluff.
# Processing Record 15. Fetched Shingu.
# Processing Record 16. Fetched Ponta do Sol.
# Processing Record 17. Fetched Chokurdakh.
# Processing Record 18. Fetched Taywarah.
# Processing Record 19. Fetched Bageshwar.
# Processing Record 20. Fetched Oriximina.
# Processing Record 21. Fetched Puerto Ayora.
# Processing Record 22. Fetched Najran.
# Processing Record 23. Fetched Hilo.
# Processing Record 24. Fetched Mana.
# Processing Record 25. Fetched Punta Arenas.
# chagda not found. Skipping.....
# Processing Record 26. Fetched Mataura.
# Processing Record 27. Fetched Yellowknife.
# Processing Record 28. Fetched Cidreira.
# Processing Record 29. Fetched Road Town.
# Processing Record 30. Fetched Penzance.
# Processing Record 31. Fetched Hobbs.
# Processing Record 32. Fetched Bethel.
# Processing Record 33. Fetched Madison.
# taolanaro not found. Skipping.....
# Processing Record 34. Fetched Hovezi.
# Processing Record 35. Fetched Qaanaaq.
# Processing Record 36. Fetched San Quintin.
# Processing Record 37. Fetched Arraial do Cabo.
# Processing Record 38. Fetched Lebu.
# Processing Record 39. Fetched Itaituba.
# Processing Record 40. Fetched Ciudad Lazaro Cardenas.
# barentsburg not found. Skipping.....
# Processing Record 41. Fetched Mayo.
# Processing Record 42. Fetched Vaini.
# Processing Record 43. Fetched Sabang.
# Processing Record 44. Fetched George Town.
# Processing Record 45. Fetched Cape Town.
# Processing Record 46. Fetched Thompson.
# Processing Record 47. Fetched Norman Wells.
# Processing Record 48. Fetched Walvis Bay.
# Processing Record 49. Fetched Airai.
# Processing Record 50. Fetched Lebanon.
# Processing Record 51. Fetched Kapaa.
# Processing Record 52. Fetched Bambous Virieux.
# Processing Record 53. Fetched Buchanan.
# Processing Record 119. Fetched Taylor.
# Processing Record 120. Fetched Nha Trang.
# Processing Record 121. Fetched Mahanoro.
# Processing Record 122. Fetched Hamilton.
# Processing Record 123. Fetched Vestmanna.
# Processing Record 124. Fetched Kahului.
# Processing Record 125. Fetched Hobart.
# Processing Record 126. Fetched Idrinskoye.
# Processing Record 127. Fetched Bocana de Paiwas.
# Processing Record 128. Fetched Trincomalee.
# Processing Record 129. Fetched Katsuura.
# Processing Record 130. Fetched Terrace.
# Processing Record 131. Fetched Port Alfred.
# Processing Record 132. Fetched Qasigiannguit.
# tumannyy not found. Skipping.....
# Processing Record 133. Fetched Kiama.
# Processing Record 134. Fetched Sur.
# Processing Record 135. Fetched Khatanga.
# Processing Record 136. Fetched Torbay.
# Processing Record 137. Fetched Nhulunbuy.
# Processing Record 138. Fetched Troitskoye.
# Processing Record 139. Fetched Nizhniy Lomov.
# Processing Record 140. Fetched Lavrentiya.
# Processing Record 141. Fetched Itarema.
# wahran not found. Skipping.....
# Processing Record 142. Fetched Iqaluit.
# Processing Record 143. Fetched Porto-Novo.
# illoqqortoormiut not found. Skipping.....
# Processing Record 144. Fetched Leshan.
# Processing Record 145. Fetched Menongue.
# Processing Record 146. Fetched Bara.
# Processing Record 147. Fetched Faya.
# Processing Record 148. Fetched Palenque.
# Processing Record 149. Fetched Ribeira Grande.
# Processing Record 150. Fetched Kehtna.
# Processing Record 151. Fetched Presidencia Roque Saenz Pena.
# Processing Record 152. Fetched Narsaq.
# Processing Record 153. Fetched Jinji.
# Processing Record 154. Fetched Khandyga.
# Processing Record 155. Fetched Northam.
# Processing Record 156. Fetched Kamra.
# Processing Record 157. Fetched Kaeo.
# Processing Record 158. Fetched Cabo San Lucas.
# nizhneyansk not found. Skipping.....
# Processing Record 159. Fetched East London.
# Processing Record 160. Fetched Ambilobe.
# Processing Record 161. Fetched Berdigestyakh.
# Processing Record 162. Fetched Beringovskiy.
# Processing Record 163. Fetched Porbandar.
# Processing Record 164. Fetched Oussouye.
# Processing Record 165. Fetched Fort Nelson.
# Processing Record 166. Fetched Aksha.
# Processing Record 167. Fetched Verkhnevilyuysk.
# Processing Record 168. Fetched Tasiilaq.
# Processing Record 169. Fetched Key West.
# Processing Record 170. Fetched Castro.
# Processing Record 171. Fetched Jamestown.
# Processing Record 172. Fetched Mnogovershinnyy.
# Processing Record 173. Fetched Mahebourg.
# Processing Record 174. Fetched Darlowo.
# Processing Record 175. Fetched Carnarvon.
# Processing Record 176. Fetched Yulara.
# Processing Record 177. Fetched Riachao das Neves.
# Processing Record 178. Fetched West Wendover.
# Processing Record 179. Fetched Saint-Pierre.
# Processing Record 180. Fetched Bataipora.
# Processing Record 181. Fetched Mpongwe.
# Processing Record 182. Fetched Lompoc.
# Processing Record 183. Fetched Kavieng.
# Processing Record 184. Fetched Chagoda.
# Processing Record 185. Fetched Hong Kong.
# Processing Record 253. Fetched Chengde.
# Processing Record 254. Fetched Yuanping.
# Processing Record 255. Fetched Clyde River.
# Processing Record 256. Fetched Boralday.
# Processing Record 257. Fetched Nome.
# Processing Record 258. Fetched Oktyabrskiy.
# Processing Record 259. Fetched Okhotsk.
# Processing Record 260. Fetched Durant.
# Processing Record 261. Fetched Poso.
# Processing Record 262. Fetched Fuerte Olimpo.
# Processing Record 263. Fetched Sechura.
# Processing Record 264. Fetched Vallenar.
# Processing Record 265. Fetched Solnechnyy.
# Processing Record 266. Fetched Asau.
# grand river south east not found. Skipping.....
# skagastrond not found. Skipping.....
# Processing Record 267. Fetched Beloha.
# Processing Record 268. Fetched Havelock.
# Processing Record 269. Fetched Chifeng.
# Processing Record 270. Fetched Srednekolymsk.
# Processing Record 271. Fetched San Jose.
# louisbourg not found. Skipping.....
# Processing Record 272. Fetched Chui.
# Processing Record 273. Fetched Mahon.
# Processing Record 274. Fetched Balakhta.
# Processing Record 275. Fetched Nouadhibou.
# Processing Record 276. Fetched Medea.
# Processing Record 277. Fetched Balaipungut.
# Processing Record 278. Fetched Xingyi.
# Processing Record 279. Fetched Kihei.
# Processing Record 280. Fetched Challapata.
# Processing Record 281. Fetched Tres Palos.
# Processing Record 282. Fetched Ciudad del Carmen.
# Processing Record 283. Fetched Tambo.
# Processing Record 284. Fetched Nemuro.
# Processing Record 285. Fetched Flinders.
# Processing Record 286. Fetched Port Lincoln.
# Processing Record 287. Fetched Bengkulu.
# Processing Record 288. Fetched Mokokchung.
# Processing Record 289. Fetched Westonaria.
# Processing Record 290. Fetched San Miguel.
# Processing Record 291. Fetched Port Blair.
# Processing Record 292. Fetched Ramtek.
# Processing Record 293. Fetched Gladstone.
# Processing Record 294. Fetched Tottori.
# Processing Record 295. Fetched Half Moon Bay.
# karaul not found. Skipping.....
# Processing Record 296. Fetched Nioro.
# Processing Record 297. Fetched Padre Bernardo.
# Processing Record 298. Fetched Mujiayingzi.
# Processing Record 299. Fetched Hasaki.
# umm durman not found. Skipping.....
# Processing Record 300. Fetched Lunavada.
# Processing Record 301. Fetched Inirida.
# Processing Record 302. Fetched Sao Joao da Barra.
# Processing Record 303. Fetched Aklavik.
# Processing Record 304. Fetched Hofn.
# Processing Record 305. Fetched Pevek.
# Processing Record 306. Fetched Ahipara.
# Processing Record 307. Fetched Padang.
# amderma not found. Skipping.....
# Processing Record 308. Fetched Ihosy.
# Processing Record 309. Fetched Abha.
# Processing Record 310. Fetched Morondava.
# Processing Record 311. Fetched Provideniya.
# Processing Record 312. Fetched Sitka.
# Processing Record 313. Fetched Cherskiy.
# Processing Record 314. Fetched Pasni.
# Processing Record 315. Fetched Barcelona.
# Processing Record 316. Fetched Peruibe.
# Processing Record 317. Fetched Jalu.
# Processing Record 318. Fetched Atikokan.
# Processing Record 319. Fetched Mount Gambier.
# Processing Record 320. Fetched Poum.
# Processing Record 321. Fetched Acajutla.
# Processing Record 322. Fetched Puerto Escondido.
# Processing Record 323. Fetched North Myrtle Beach.
# Processing Record 324. Fetched Ola.
# Processing Record 325. Fetched Fortuna.
# Processing Record 326. Fetched Murray Bridge.
# Processing Record 327. Fetched Dingle.
# Processing Record 328. Fetched Saint George's.
# Processing Record 329. Fetched Weiden.
# Processing Record 330. Fetched Pitimbu.
# Processing Record 331. Fetched Wadena.
# Processing Record 332. Fetched Santa Rosa.
# Processing Record 333. Fetched Buala.
# Processing Record 334. Fetched Quatre Cocos.
# Processing Record 335. Fetched Kaitangata.
# Processing Record 336. Fetched Morrope.
# Processing Record 337. Fetched Cedar City.
# Processing Record 338. Fetched Esna.
# Processing Record 339. Fetched Maridi.
# Processing Record 340. Fetched Hirara.
# Processing Record 341. Fetched Deputatsky.
# bolungarvik not found. Skipping.....
# Processing Record 342. Fetched Wellington.
# Processing Record 343. Fetched Buluang.
# kamenskoye not found. Skipping.....
# Processing Record 344. Fetched Tura.
# yunjinghong not found. Skipping.....
# Processing Record 345. Fetched San Rafael.
# Processing Record 346. Fetched Stykkisholmur.
# Processing Record 347. Fetched Karratha.
# Processing Record 348. Fetched Saskylakh.
# Processing Record 349. Fetched Sakakah.
# Processing Record 350. Fetched Yumen.
# Processing Record 351. Fetched Tessalit.
# Processing Record 352. Fetched Orda.
# Processing Record 353. Fetched Aripuana.
# Processing Record 354. Fetched Bayanday.
# Processing Record 355. Fetched Camabatela.
# Processing Record 356. Fetched Roald.
# Processing Record 357. Fetched Tortoli.
# Processing Record 358. Fetched Gamba.
# Processing Record 359. Fetched Cacoal.
# Processing Record 360. Fetched Moron.
# Processing Record 361. Fetched Port Elizabeth.
# Processing Record 362. Fetched Youghal.
# Processing Record 363. Fetched Hambantota.
# Processing Record 364. Fetched Sao Goncalo do Amarante.
# Processing Record 365. Fetched Novhorodka.
# Processing Record 366. Fetched Japura.
# Processing Record 367. Fetched Saint-Marc-des-Carrieres.
# dzhusaly not found. Skipping.....
# Processing Record 368. Fetched Berriozabal.
# Processing Record 369. Fetched Bria.
# Processing Record 370. Fetched Ankara.
# Processing Record 371. Fetched General Roca.
# Processing Record 372. Fetched Saint-Francois.
# Processing Record 373. Fetched Antalaha.
# Processing Record 374. Fetched Ierapetra.
# Processing Record 375. Fetched Turukhansk.
# Processing Record 376. Fetched Margate.
# Processing Record 377. Fetched Joshimath.
# Processing Record 378. Fetched Soledad.
# Processing Record 379. Fetched Portland.
# Processing Record 380. Fetched Juybar.
# Processing Record 381. Fetched Sobolevo.
# Processing Record 382. Fetched Saint Anthony.
# Processing Record 383. Fetched Ohara.
# Processing Record 384. Fetched Mossoro.
# Processing Record 385. Fetched Miracema do Tocantins.
# Processing Record 386. Fetched Sri Aman.
# kargapolye not found. Skipping.....
# galgani not found. Skipping.....
# Processing Record 387. Fetched Harar.
# Processing Record 388. Fetched Obo.
# Processing Record 389. Fetched Pokhara.
# Processing Record 390. Fetched Alyangula.
# Processing Record 391. Fetched Chino Valley.
# Processing Record 392. Fetched San Luis.
# Processing Record 393. Fetched Bilma.
# Processing Record 394. Fetched Tefe.
# Processing Record 395. Fetched Salinopolis.
# Processing Record 396. Fetched Manado.
# Processing Record 397. Fetched Tabas.
# Processing Record 398. Fetched Cayenne.
# Processing Record 399. Fetched Yinchuan.
# Processing Record 400. Fetched Longhua.
# Processing Record 401. Fetched Tuni.
# Processing Record 402. Fetched Astana.
# Processing Record 403. Fetched Santa Maria del Oro.
# Processing Record 404. Fetched Tukrah.
# Processing Record 405. Fetched Salalah.
# Processing Record 406. Fetched Poya.
# Processing Record 407. Fetched Saint Andrews.
# Processing Record 408. Fetched Riwaka.
# Processing Record 409. Fetched Pinyug.
# Processing Record 410. Fetched San Cristobal.
# Processing Record 411. Fetched Ketchikan.
# Processing Record 412. Fetched Bonavista.
# Processing Record 413. Fetched Shimoni.
# Processing Record 414. Fetched Ode.
# Processing Record 415. Fetched Kasempa.
# Processing Record 416. Fetched Inhambane.
# Processing Record 417. Fetched College.
# Processing Record 418. Fetched Hede.
# Processing Record 419. Fetched Khokhlovo.
# Processing Record 420. Fetched Raigarh.
# toliary not found. Skipping.....
# Processing Record 421. Fetched Camacha.
# Processing Record 422. Fetched Qeshm.
# Processing Record 423. Fetched Winnemucca.
# Processing Record 424. Fetched Mizdah.
# qandahar not found. Skipping.....
# Processing Record 425. Fetched Naze.
# Processing Record 426. Fetched Carballo.
# Processing Record 427. Fetched Oistins.
# Processing Record 428. Fetched Sidi Ali.
# Processing Record 429. Fetched Kenai.
# hunza not found. Skipping.....
# Processing Record 430. Fetched Malpe.
# marcona not found. Skipping.....
# Processing Record 431. Fetched Ambovombe.
# Processing Record 432. Fetched Portoviejo.
# Processing Record 433. Fetched Riyadh.
# Processing Record 434. Fetched Houston.
# Processing Record 435. Fetched Mandalgovi.
# Processing Record 436. Fetched Darnah.
# Processing Record 437. Fetched Hagondange.
# Processing Record 438. Fetched Mogadishu.
# Processing Record 439. Fetched Mareeba.
# Processing Record 440. Fetched Pangkalanbuun.
# Processing Record 441. Fetched Kununurra.
# Processing Record 442. Fetched Gien.
# Processing Record 443. Fetched Nizhniy Kuranakh.
# Processing Record 444. Fetched Tabou.
# Processing Record 445. Fetched Kerema.
# Processing Record 446. Fetched Mossamedes.
# Processing Record 447. Fetched Port Macquarie.
# Processing Record 448. Fetched Luau.
# sedelnikovo not found. Skipping.....
# Processing Record 449. Fetched Le Pont-de-Claix.
# Processing Record 450. Fetched Puerto Asis.
# Processing Record 451. Fetched Luanda.
# Processing Record 452. Fetched Isangel.
# Processing Record 453. Fetched Stephenville.
# Processing Record 454. Fetched Jizan.
# Processing Record 455. Fetched Akhmeta.
# Processing Record 456. Fetched Rassvet.
# Processing Record 457. Fetched Bambanglipuro.
# Processing Record 458. Fetched Totness.
# Processing Record 459. Fetched Guangyuan.
# Processing Record 460. Fetched Sambava.
# Processing Record 461. Fetched Noumea.
# Processing Record 462. Fetched Offenburg.
# Processing Record 463. Fetched Kuantan.
# Processing Record 464. Fetched Manaure.
# Processing Record 465. Fetched Gualaquiza.
# Processing Record 466. Fetched Bath.
# Processing Record 467. Fetched Dalnerechensk.
# Processing Record 468. Fetched Saint-Michel-des-Saints.
# Processing Record 469. Fetched Port Said.
# Processing Record 470. Fetched Svetlaya.
# Processing Record 471. Fetched Verkhniy Avzyan.
# Processing Record 472. Fetched Templin.
# Processing Record 473. Fetched Tuatapere.
# Processing Record 474. Fetched Cam Ranh.
# Processing Record 475. Fetched Motril.
# Processing Record 476. Fetched Ndola.
# el balyana not found. Skipping.....
# Processing Record 477. Fetched Kadoma.
# Processing Record 478. Fetched Yuncheng.
# Processing Record 479. Fetched Mpanda.
# Processing Record 480. Fetched Broome.
# Processing Record 481. Fetched Bodden Town.
# Processing Record 482. Fetched Buraidah.
# Processing Record 483. Fetched Jingdezhen.
# Processing Record 484. Fetched Kitimat.
# Processing Record 485. Fetched Coyhaique.
# Processing Record 486. Fetched Skjervoy.
# Processing Record 487. Fetched Kalagarh Project Colony.
# Processing Record 488. Fetched Aktobe.
# Processing Record 489. Fetched Daru.
# Processing Record 490. Fetched Ballina.
# Processing Record 491. Fetched Taoudenni.
# Processing Record 492. Fetched Coquimbo.
# Processing Record 493. Fetched Gondanglegi.
# Processing Record 494. Fetched Sabzevar.
# Processing Record 495. Fetched Los Llanos de Aridane.
# Processing Record 496. Fetched Dolores.
# Processing Record 497. Fetched Carberry.
# Processing Record 498. Fetched Dolzhanskaya.
# Processing Record 499. Fetched Talnakh.
# Processing Record 500. Fetched Halifax.
# Processing Record 501. Fetched Hasanabad.
# Processing Record 502. Fetched Morgan City.
# Processing Record 503. Fetched Mutis.
# Processing Record 504. Fetched Yanam.
# Processing Record 505. Fetched Sola.
# Processing Record 506. Fetched Pilar.
# Processing Record 507. Fetched Ukiah.
# Processing Record 508. Fetched Eilat.
# Processing Record 509. Fetched Amapa.
# malwan not found. Skipping.....
# Processing Record 510. Fetched Sarmas.
# Processing Record 511. Fetched Havre-Saint-Pierre.
# Processing Record 512. Fetched Mayumba.
# Processing Record 513. Fetched Santa Maria.
# Processing Record 514. Fetched Matamoros.
# Processing Record 515. Fetched Trofors.
# Processing Record 516. Fetched Ban Nahin.
# Processing Record 517. Fetched Borgarnes.
# Processing Record 518. Fetched Robertsport.
# dekoa not found. Skipping.....
# Processing Record 519. Fetched Lodja.
# Processing Record 520. Fetched Bukama.
# Processing Record 521. Fetched Glencoe.
# Processing Record 522. Fetched Sorong.
# alotau not found. Skipping.....
# Processing Record 523. Fetched Qashyr.
# Processing Record 524. Fetched Cosala.
# Processing Record 525. Fetched Port Moresby.
# Processing Record 526. Fetched Novska.
# Processing Record 527. Fetched Tommot.
# Processing Record 528. Fetched Chicama.
# Processing Record 529. Fetched Lorengau.
# Processing Record 530. Fetched Barra Patuca.
# Processing Record 531. Fetched Bahia Honda.
# Processing Record 532. Fetched Yangi Marg`ilon.
# Processing Record 533. Fetched Belmonte.
# Processing Record 534. Fetched Linxia.
# Processing Record 535. Fetched Izhma.
# Processing Record 536. Fetched Alice Springs.
# Processing Record 537. Fetched Mtwara.
# Processing Record 538. Fetched Yinzhu.
# Processing Record 539. Fetched Kropotkin.
# Processing Record 540. Fetched City of San Pedro.
# Processing Record 541. Fetched Vardo.
# Processing Record 542. Fetched Muscatine.
# Processing Record 543. Fetched Gizo.
# Processing Record 544. Fetched Tigil.
# Processing Record 545. Fetched Aquiraz.
# Processing Record 546. Fetched Nakhon Thai.
# Processing Record 547. Fetched Rosetta.
# Processing Record 548. Fetched Nikolayevsk-on-Amure.
# Processing Record 549. Fetched Ust-Nera.
# visimo-utkinsk not found. Skipping.....
# Processing Record 550. Fetched Fayaoue.
# Processing Record 551. Fetched Ostrovnoy.
# Processing Record 552. Fetched Bud.
# Processing Record 553. Fetched Dhidhdhoo.
# Processing Record 554. Fetched Alofi.
# Processing Record 555. Fetched Ayr.
# Processing Record 556. Fetched Safi.
# Processing Record 557. Fetched Zhezkazgan.
# Processing Record 558. Fetched Zamora.
# Processing Record 559. Fetched Turinsk.
# Processing Record 560. Fetched Kedrovka.
# Processing Record 561. Fetched Champerico.
# Processing Record 562. Fetched Mananara.
# Processing Record 563. Fetched Rutul.
# Processing Record 564. Fetched Llanes.
# lolua not found. Skipping.....
# Processing Record 565. Fetched Carutapera.
# Processing Record 566. Fetched Shimoda.
# Processing Record 567. Fetched Laas.
# Processing Record 568. Fetched Borgo San Dalmazzo.
# Processing Record 569. Fetched Sao Gabriel da Cachoeira.
# Processing Record 570. Fetched Gatak.
# Processing Record 571. Fetched Tocopilla.
# Processing Record 572. Fetched Kavali.
# Processing Record 573. Fetched Miyazu.
# Processing Record 574. Fetched Lar.
# Processing Record 575. Fetched Gushikawa.
# Processing Record 576. Fetched Belyy Yar.

# %%
cities = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []
size = len(cities_weather)
counter = 0
pct = 0
for weather in cities_weather:
    cities.append(weather['name'])
    cloudiness.append(weather['clouds']['all'])
    country.append(weather['sys']['country'])
    date.append(weather['dt'])
    humidity.append(weather['main']['humidity'])
    latitude.append(weather['coord']['lat'])
    longitude.append(weather['coord']['lon'])
    max_temp.append(weather['main']['temp_max'])
    wind_speed.append(weather['wind']['speed'])
    counter = counter + 1
    sys.stdout.write('\r')
    pct = (counter/size) * 100
    sys.stdout.write("[%-100s] %d%%" % ('█'*int(pct), pct))
    sys.stdout.flush()
# Out:
# [████████████████████████████████████████████████████████████████████████████████████████████████████] 100%

# %%
weather_df = pd.DataFrame({
    'City': cities,
    'Cloudiness' : cloudiness,
    'Country' : country,
    'Date' : date,
    'Humidity' : humidity,
    'Lat' : latitude,
    'Lon' : longitude,
    'Max Temp' : max_temp,
    'Wind Speed' : wind_speed
})
weather_df.dropna()
print("Created data frame")
# Out:
# Created data frame

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Output to CSV
weather_df.to_csv(output_data_file)

# %%
weather_df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0  Arraial do Cabo          75      BR  1578998342        78 -22.97  -42.03
# 1         Khatanga          49      RU  1578998583        88  71.97  102.50
# 2         Hermanus          36      ZA  1578998583        49 -34.42   19.23
# 3           Sumter          20      US  1578998583        93  28.71  -82.08
# 4     Puerto Ayora          69      EC  1578998584        75  -0.74  -90.35
#
#    Max Temp  Wind Speed
# 0     77.00        3.36
# 1    -19.68        7.61
# 2     90.00        4.00
# 3     66.99        3.13
# 4     75.99        8.01

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Create a plotter function
def plotter(factor='Max Temp'):
    x_axis = weather_df['Lat']
    y_axis = weather_df[f'{factor}']
    
    plt.title(f"Latitude vs. {factor} Plot")
    if factor == 'Max Temp': 
        plt.title(f"Latitude vs. Temperature Plot")
        
    plt.xlabel("Latitude")
    plt.ylabel(f'{factor}')

    plt.scatter(x_axis, y_axis, marker='o', facecolors="steelblue", edgecolors="black", alpha=0.75)
    plt.grid()
    plt.savefig(f"output_data/Latitude_Vs_{factor}.png")
    plt.show()

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plotter('Max Temp')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plotter('Humidity')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plotter('Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plotter('Wind Speed')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linregplotter( factor='Max Temp', where='north'):
    plt.clf()
    if where == "north":
        x_values = northern_df["Lat"]
        y_values = northern_df[f'{factor}']
    elif where == "south":
        x_values = southern_df["Lat"]
        y_values = southern_df[f'{factor}']
        
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
    regression_values = x_values * slope + intercept
    line_eq = f"y = {round(slope, 2)}x + {round(intercept,2)}"
    print(f"The r-squared is :{rvalue}\n")

    plt.scatter(x_values, y_values, facecolors="steelblue")
    plt.plot(x_values, regression_values, 'r-')
    plt.annotate(line_eq, (min(x_values)+5, min(y_values)+5), fontsize=15, color="red")

    plt.title(f"Latitude vs. {factor} Plot")
    plt.xlabel("Latitude")
    plt.ylabel(f"{factor} Plot")
    plt.savefig(f"output_data/LinReg_Latitude_Vs_{factor}_{where.upper()}.png")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[weather_df['Lat'] >= 0,:]
southern_df = weather_df.loc[weather_df['Lat'] < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linregplotter('Max Temp', 'north')
# Out:
# The r-squared is :-0.8445593620816617

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linregplotter('Max Temp', 'south')
# Out:
# The r-squared is :0.4803300535931871

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linregplotter('Humidity', 'north')
# Out:
# The r-squared is :0.394946561940803

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linregplotter('Humidity', 'south')
# Out:
# The r-squared is :0.11129390060576196

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linregplotter('Cloudiness', 'north')
# Out:
# The r-squared is :0.31685704482537613

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linregplotter('Cloudiness', 'south')
# Out:
# The r-squared is :0.10516269122069768

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linregplotter('Wind Speed', 'north')
# Out:
# The r-squared is :0.11154791657103894

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linregplotter('Wind Speed', 'south')
# Out:
# The r-squared is :-0.23170311114361636

# %%
# Out:
# 590
